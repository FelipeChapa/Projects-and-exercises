# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
from flatten_json import flatten

# %%
lat = 0
long = 0
url = "https://power.larc.nasa.gov/cgi-bin/v1/DataAccess.py?&request=execute&identifier=SinglePoint&parameters=SI_EF_TILTED_SURFACE&userCommunity=SSE&tempAverage=CLIMATOLOGY&outputList=CSV&lat={}&lon={}".format(lat, long)

# %%
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
location_data = pd.DataFrame({'lat':[0,1,1.5],'long':[0,-1,-1.5],'Site':["Ecuador","Tula","Mexicali"]})
location_data
# Out:
#    lat  long      Site
# 0  0.0   0.0   Ecuador
# 1  1.0  -1.0      Tula
# 2  1.5  -1.5  Mexicali

# %%
solar_radiance= response.json()
solar_radiance=solar_radiance['features'][0]['properties']

solar_radiance
# Out:
# {'parameter': {'SI_EF_OPTIMAL': [5.77,
#    5.65,
#    5.74,
#    5.7,
#    5.62,
#    5.93,
#    5.83,
#    5.63,
#    5.78,
#    5.63,
#    5.61,
#    5.66,
#    5.71],
#   'SI_EF_OPTIMAL_ANG': [22.5,
#    14.0,
#    2.5,
#    -10.5,
#    -21.0,
#    -26.5,
#    -24.0,
#    -15.0,
#    -2.5,
#    10.0,
#    20.0,
#    24.5,
#    -0.5],
#   'SI_EF_OPTIMAL_ANG_ORT': ['S',
#    'S',
#    'S',
#    'N',
#    'N',
#    'N',
#    'N',
#    'N',
#    'N',
#    'S',
#    'S',
#    'S',
#    'N'],
#   'SI_EF_TILTED_SURFACE_HORIZONTAL': [5.41,
#    5.52,
#    5.73,
#    5.63,
#    5.33,
#    5.43,
#    5.42,
#    5.48,
#    5.78,
#    5.56,
#    5.34,
#    5.25,
#    5.49],
#   'SI_EF_TILTED_SURFACE_LATITUDE': [5.41,
#    5.52,
#    5.73,
#    5.63,
#    5.33,
#    5.43,
#    5.42,
#    5.48,
#    5.78,
#    5.56,
#    5.34,
#    5.25,
#    5.49],
#   'SI_EF_TILTED_SURFACE_LAT_MINUS15': [4.81,
#    5.09,
#    5.53,
#    5.69,
#    5.6,
#    5.84,
#    5.77,
#    5.63,
#    5.67,
#    5.21,
#    4.8,
#    4.61,
#    5.35],
#   'SI_EF_TILTED_SURFACE_LAT_PLUS15': [5.73,
#    5.65,
#    5.63,
#    5.27,
#    4.78,
#    4.73,
#    4.78,
#    5.04,
#    5.57,
#    5.61,
#    5.59,
#    5.6,
#    5.33],
#   'SI_EF_TILTED_SURFACE_VERTICAL': [2.9,
#    2.24,
#    1.46,
#    1.23,
#    1.16,
#    1.1,
#    1.13,
#    1.29,
#    1.22,
#    1.98,
#    2.68,
#    3.0,
#    1.78],
#   'SI_EF_TRACKER': [6.73,
#    6.65,
#    6.79,
#    6.77,
#    6.61,
#    7.02,
#    6.91,
#    6.69,
#    6.89,
#    6.62,
#    6.53,
#    6.57,
#    6.73]}}

# %%
solar_radiance= response.json()
solar_radiance=solar_radiance['features'][0]['properties']['parameter']
lat_long = response.json()
df = pd.DataFrame.from_dict(solar_radiance,orient='index').reset_index()
df
# Out:
#                               index     0     1     2     3     4     5     6  \
# 0                     SI_EF_OPTIMAL  5.77  5.65  5.74   5.7  5.62  5.93  5.83
# 1                 SI_EF_OPTIMAL_ANG  22.5    14   2.5 -10.5   -21 -26.5   -24
# 2             SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N     N
# 3   SI_EF_TILTED_SURFACE_HORIZONTAL  5.41  5.52  5.73  5.63  5.33  5.43  5.42
# 4     SI_EF_TILTED_SURFACE_LATITUDE  5.41  5.52  5.73  5.63  5.33  5.43  5.42
# 5  SI_EF_TILTED_SURFACE_LAT_MINUS15  4.81  5.09  5.53  5.69   5.6  5.84  5.77
# 6   SI_EF_TILTED_SURFACE_LAT_PLUS15  5.73  5.65  5.63  5.27  4.78  4.73  4.78
# 7     SI_EF_TILTED_SURFACE_VERTICAL   2.9  2.24  1.46  1.23  1.16   1.1  1.13
# 8                     SI_EF_TRACKER  6.73  6.65  6.79  6.77  6.61  7.02  6.91
#
#       7     8     9    10    11    12
# 0  5.63  5.78  5.63  5.61  5.66  5.71
# 1   -15  -2.5    10    20  24.5  -0.5
# 2     N     N     S     S     S     N
# 3  5.48  5.78  5.56  5.34  5.25  5.49
# 4  5.48  5.78  5.56  5.34  5.25  5.49
# 5  5.63  5.67  5.21   4.8  4.61  5.35
# 6  5.04  5.57  5.61  5.59   5.6  5.33
# 7  1.29  1.22  1.98  2.68     3  1.78
# 8  6.69  6.89  6.62  6.53  6.57  6.73

# %%
parameter_info= response.json()['parameterInformation'][1]
parameter_info
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-bb6dd824b054> in <module>
# ----> 1 parameter_info= response.json()['parameterInformation'][1]
#       2 parameter_info
#
# KeyError: 1

# %%
def get_lat_long(response):
    lat_long = response.json()['features'][0]['geometry']['coordinates'][0:2]
    return lat_long
get_lat_long(response)
# Out:
# [1e-05, 1e-05]

# %%
df['lat'] = lat_long[0]
df['long'] = lat_long[1]
df
# Out:
#                               index     0     1     2     3     4     5     6  \
# 0                     SI_EF_OPTIMAL  5.77  5.65  5.74   5.7  5.62  5.93  5.83
# 1                 SI_EF_OPTIMAL_ANG  22.5    14   2.5 -10.5   -21 -26.5   -24
# 2             SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N     N
# 3   SI_EF_TILTED_SURFACE_HORIZONTAL  5.41  5.52  5.73  5.63  5.33  5.43  5.42
# 4     SI_EF_TILTED_SURFACE_LATITUDE  5.41  5.52  5.73  5.63  5.33  5.43  5.42
# 5  SI_EF_TILTED_SURFACE_LAT_MINUS15  4.81  5.09  5.53  5.69   5.6  5.84  5.77
# 6   SI_EF_TILTED_SURFACE_LAT_PLUS15  5.73  5.65  5.63  5.27  4.78  4.73  4.78
# 7     SI_EF_TILTED_SURFACE_VERTICAL   2.9  2.24  1.46  1.23  1.16   1.1  1.13
# 8                     SI_EF_TRACKER  6.73  6.65  6.79  6.77  6.61  7.02  6.91
#
#       7     8     9    10    11    12      lat     long
# 0  5.63  5.78  5.63  5.61  5.66  5.71  0.00001  0.00001
# 1   -15  -2.5    10    20  24.5  -0.5  0.00001  0.00001
# 2     N     N     S     S     S     N  0.00001  0.00001
# 3  5.48  5.78  5.56  5.34  5.25  5.49  0.00001  0.00001
# 4  5.48  5.78  5.56  5.34  5.25  5.49  0.00001  0.00001
# 5  5.63  5.67  5.21   4.8  4.61  5.35  0.00001  0.00001
# 6  5.04  5.57  5.61  5.59   5.6  5.33  0.00001  0.00001
# 7  1.29  1.22  1.98  2.68     3  1.78  0.00001  0.00001
# 8  6.69  6.89  6.62  6.53  6.57  6.73  0.00001  0.00001

# %%
df2 = pd.DataFrame()
for n_sites in location_data[["lat","long"]].to_numpy():
    print(n_sites,end='')
    lat = n_sites[0]
    long =n_sites[1]
    print("...done")
    url = "https://power.larc.nasa.gov/cgi-bin/v1/DataAccess.py?&request=execute&identifier=SinglePoint&parameters=SI_EF_TILTED_SURFACE&userCommunity=SSE&tempAverage=CLIMATOLOGY&outputList=CSV&lat={}&lon={}".format(lat, long) 
    response = requests.get(url)
    solar_radiance=response.json()['features'][0]['properties']['parameter']
    newdf = pd.DataFrame.from_dict(solar_radiance,orient='index').reset_index()
    newdf['lat'] = lat
    newdf['long'] = long
    df2= df2.append(newdf,ignore_index=True)
print(n_sites,"...all done")
# Out:
# [0. 0.] ...done
# [ 1. -1.] ...done
# [ 1.5 -1.5] ...done
# [ 1.5 -1.5] ...all done

# %%
df2
# Out:
#                                index     0     1     2     3     4     5  \
# 0                      SI_EF_OPTIMAL  5.77  5.65  5.74   5.7  5.62  5.93
# 1                  SI_EF_OPTIMAL_ANG  22.5    14   2.5 -10.5   -21 -26.5
# 2              SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N
# 3    SI_EF_TILTED_SURFACE_HORIZONTAL  5.41  5.52  5.73  5.63  5.33  5.43
# 4      SI_EF_TILTED_SURFACE_LATITUDE  5.41  5.52  5.73  5.63  5.33  5.43
# 5   SI_EF_TILTED_SURFACE_LAT_MINUS15  4.81  5.09  5.53  5.69   5.6  5.84
# 6    SI_EF_TILTED_SURFACE_LAT_PLUS15  5.73  5.65  5.63  5.27  4.78  4.73
# 7      SI_EF_TILTED_SURFACE_VERTICAL   2.9  2.24  1.46  1.23  1.16   1.1
# 8                      SI_EF_TRACKER  6.73  6.65  6.79  6.77  6.61  7.02
# 9                      SI_EF_OPTIMAL  5.69  5.87  5.72  5.57  5.17  5.63
# 10                 SI_EF_OPTIMAL_ANG  23.5    15   3.5  -9.5   -19 -24.5
# 11             SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N
# 12   SI_EF_TILTED_SURFACE_HORIZONTAL  5.32  5.71  5.71  5.52  4.95  5.22
# 13     SI_EF_TILTED_SURFACE_LATITUDE  5.35  5.73  5.71  5.51  4.93  5.19
# 14  SI_EF_TILTED_SURFACE_LAT_MINUS15  4.75  5.27  5.51  5.56  5.15  5.56
# 15   SI_EF_TILTED_SURFACE_LAT_PLUS15  5.65  5.87  5.61  5.16  4.45  4.55
# 16     SI_EF_TILTED_SURFACE_VERTICAL  2.92  2.36  1.52  1.22  1.18   1.1
# 17                     SI_EF_TRACKER  6.64     7  6.75  6.56  5.95  6.58
# 18                     SI_EF_OPTIMAL  5.69   5.9  5.75  5.52   5.1  5.69
# 19                 SI_EF_OPTIMAL_ANG  23.5  15.5     4    -9   -18   -24
# 20             SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N
# 21   SI_EF_TILTED_SURFACE_HORIZONTAL  5.31  5.73  5.74  5.47   4.9  5.29
# 22     SI_EF_TILTED_SURFACE_LATITUDE  5.35  5.76  5.75  5.45  4.87  5.23
# 23  SI_EF_TILTED_SURFACE_LAT_MINUS15  4.76   5.3  5.55   5.5  5.09  5.61
# 24   SI_EF_TILTED_SURFACE_LAT_PLUS15  5.66   5.9  5.64  5.11   4.4  4.57
# 25     SI_EF_TILTED_SURFACE_VERTICAL  2.95  2.41  1.52  1.22  1.16  1.06
# 26                     SI_EF_TRACKER  6.64  7.03   6.8  6.48  5.86  6.66
#
#        6     7     8     9    10    11    12  lat  long
# 0   5.83  5.63  5.78  5.63  5.61  5.66  5.71  0.0   0.0
# 1    -24   -15  -2.5    10    20  24.5  -0.5  0.0   0.0
# 2      N     N     N     S     S     S     N  0.0   0.0
# 3   5.42  5.48  5.78  5.56  5.34  5.25  5.49  0.0   0.0
# 4   5.42  5.48  5.78  5.56  5.34  5.25  5.49  0.0   0.0
# 5   5.77  5.63  5.67  5.21   4.8  4.61  5.35  0.0   0.0
# 6   4.78  5.04  5.57  5.61  5.59   5.6  5.33  0.0   0.0
# 7   1.13  1.29  1.22  1.98  2.68     3  1.78  0.0   0.0
# 8   6.91  6.69  6.89  6.62  6.53  6.57  6.73  0.0   0.0
# 9   5.95  5.86  5.55   5.5  5.67  5.62  5.65  1.0  -1.0
# 10   -23   -14  -1.5    11    21  25.5   0.5  1.0  -1.0
# 11     N     N     N     S     S     S     S  1.0  -1.0
# 12  5.56  5.72  5.55  5.42  5.36  5.18  5.44  1.0  -1.0
# 13  5.53   5.7  5.55  5.44  5.39  5.21  5.44  1.0  -1.0
# 14  5.89  5.86  5.45   5.1  4.84  4.59   5.3  1.0  -1.0
# 15  4.86  5.22  5.35  5.48  5.65  5.56  5.29  1.0  -1.0
# 16  1.08  1.14  1.25  2.01  2.76  3.04   1.8  1.0  -1.0
# 17  7.06     7  6.54  6.44  6.63  6.53  6.64  1.0  -1.0
# 18  5.97  5.73  5.63  5.58  5.72  5.69  5.67  1.5  -1.5
# 19 -22.5 -13.5    -1  11.5  21.5    26     1  1.5  -1.5
# 20     N     N     N     S     S     S     S  1.5  -1.5
# 21  5.59   5.6  5.63   5.5   5.4  5.22  5.45  1.5  -1.5
# 22  5.54  5.57  5.63  5.52  5.44  5.27  5.45  1.5  -1.5
# 23  5.91  5.73  5.53  5.18  4.88  4.63  5.31  1.5  -1.5
# 24  4.87  5.11  5.43  5.57  5.71  5.63   5.3  1.5  -1.5
# 25  1.05  1.18  1.24  2.06  2.82  3.11  1.82  1.5  -1.5
# 26  7.09  6.81  6.66  6.56  6.71  6.62  6.66  1.5  -1.5

# %%
df2 = pd.merge(df2,location_data,on=['lat','long'])

# %%
df2=df2.rename(columns={"index":"Parameter"})
df2
# Out:
#                            Parameter     0     1     2     3     4     5  \
# 0                      SI_EF_OPTIMAL  5.77  5.65  5.74   5.7  5.62  5.93
# 1                  SI_EF_OPTIMAL_ANG  22.5    14   2.5 -10.5   -21 -26.5
# 2              SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N
# 3    SI_EF_TILTED_SURFACE_HORIZONTAL  5.41  5.52  5.73  5.63  5.33  5.43
# 4      SI_EF_TILTED_SURFACE_LATITUDE  5.41  5.52  5.73  5.63  5.33  5.43
# 5   SI_EF_TILTED_SURFACE_LAT_MINUS15  4.81  5.09  5.53  5.69   5.6  5.84
# 6    SI_EF_TILTED_SURFACE_LAT_PLUS15  5.73  5.65  5.63  5.27  4.78  4.73
# 7      SI_EF_TILTED_SURFACE_VERTICAL   2.9  2.24  1.46  1.23  1.16   1.1
# 8                      SI_EF_TRACKER  6.73  6.65  6.79  6.77  6.61  7.02
# 9                      SI_EF_OPTIMAL  5.69  5.87  5.72  5.57  5.17  5.63
# 10                 SI_EF_OPTIMAL_ANG  23.5    15   3.5  -9.5   -19 -24.5
# 11             SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N
# 12   SI_EF_TILTED_SURFACE_HORIZONTAL  5.32  5.71  5.71  5.52  4.95  5.22
# 13     SI_EF_TILTED_SURFACE_LATITUDE  5.35  5.73  5.71  5.51  4.93  5.19
# 14  SI_EF_TILTED_SURFACE_LAT_MINUS15  4.75  5.27  5.51  5.56  5.15  5.56
# 15   SI_EF_TILTED_SURFACE_LAT_PLUS15  5.65  5.87  5.61  5.16  4.45  4.55
# 16     SI_EF_TILTED_SURFACE_VERTICAL  2.92  2.36  1.52  1.22  1.18   1.1
# 17                     SI_EF_TRACKER  6.64     7  6.75  6.56  5.95  6.58
# 18                     SI_EF_OPTIMAL  5.69   5.9  5.75  5.52   5.1  5.69
# 19                 SI_EF_OPTIMAL_ANG  23.5  15.5     4    -9   -18   -24
# 20             SI_EF_OPTIMAL_ANG_ORT     S     S     S     N     N     N
# 21   SI_EF_TILTED_SURFACE_HORIZONTAL  5.31  5.73  5.74  5.47   4.9  5.29
# 22     SI_EF_TILTED_SURFACE_LATITUDE  5.35  5.76  5.75  5.45  4.87  5.23
# 23  SI_EF_TILTED_SURFACE_LAT_MINUS15  4.76   5.3  5.55   5.5  5.09  5.61
# 24   SI_EF_TILTED_SURFACE_LAT_PLUS15  5.66   5.9  5.64  5.11   4.4  4.57
# 25     SI_EF_TILTED_SURFACE_VERTICAL  2.95  2.41  1.52  1.22  1.16  1.06
# 26                     SI_EF_TRACKER  6.64  7.03   6.8  6.48  5.86  6.66
#
#        6     7     8     9    10    11    12  lat  long      Site
# 0   5.83  5.63  5.78  5.63  5.61  5.66  5.71  0.0   0.0   Ecuador
# 1    -24   -15  -2.5    10    20  24.5  -0.5  0.0   0.0   Ecuador
# 2      N     N     N     S     S     S     N  0.0   0.0   Ecuador
# 3   5.42  5.48  5.78  5.56  5.34  5.25  5.49  0.0   0.0   Ecuador
# 4   5.42  5.48  5.78  5.56  5.34  5.25  5.49  0.0   0.0   Ecuador
# 5   5.77  5.63  5.67  5.21   4.8  4.61  5.35  0.0   0.0   Ecuador
# 6   4.78  5.04  5.57  5.61  5.59   5.6  5.33  0.0   0.0   Ecuador
# 7   1.13  1.29  1.22  1.98  2.68     3  1.78  0.0   0.0   Ecuador
# 8   6.91  6.69  6.89  6.62  6.53  6.57  6.73  0.0   0.0   Ecuador
# 9   5.95  5.86  5.55   5.5  5.67  5.62  5.65  1.0  -1.0      Tula
# 10   -23   -14  -1.5    11    21  25.5   0.5  1.0  -1.0      Tula
# 11     N     N     N     S     S     S     S  1.0  -1.0      Tula
# 12  5.56  5.72  5.55  5.42  5.36  5.18  5.44  1.0  -1.0      Tula
# 13  5.53   5.7  5.55  5.44  5.39  5.21  5.44  1.0  -1.0      Tula
# 14  5.89  5.86  5.45   5.1  4.84  4.59   5.3  1.0  -1.0      Tula
# 15  4.86  5.22  5.35  5.48  5.65  5.56  5.29  1.0  -1.0      Tula
# 16  1.08  1.14  1.25  2.01  2.76  3.04   1.8  1.0  -1.0      Tula
# 17  7.06     7  6.54  6.44  6.63  6.53  6.64  1.0  -1.0      Tula
# 18  5.97  5.73  5.63  5.58  5.72  5.69  5.67  1.5  -1.5  Mexicali
# 19 -22.5 -13.5    -1  11.5  21.5    26     1  1.5  -1.5  Mexicali
# 20     N     N     N     S     S     S     S  1.5  -1.5  Mexicali
# 21  5.59   5.6  5.63   5.5   5.4  5.22  5.45  1.5  -1.5  Mexicali
# 22  5.54  5.57  5.63  5.52  5.44  5.27  5.45  1.5  -1.5  Mexicali
# 23  5.91  5.73  5.53  5.18  4.88  4.63  5.31  1.5  -1.5  Mexicali
# 24  4.87  5.11  5.43  5.57  5.71  5.63   5.3  1.5  -1.5  Mexicali
# 25  1.05  1.18  1.24  2.06  2.82  3.11  1.82  1.5  -1.5  Mexicali
# 26  7.09  6.81  6.66  6.56  6.71  6.62  6.66  1.5  -1.5  Mexicali
